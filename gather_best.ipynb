# %%
from pathlib import Path as p

results = list(p().glob("training/*/results.csv"))
len(results)
# Out:
# 27

# %%
import pandas as pd

# For each csv, load only the last row
dfs = []
for r in results:
    df = pd.read_csv(r, index_col=0)
    # Remove every column that is not a metric
    df = df.filter(regex="metrics")
    # Before adding the cv, add a column for the F1 score
    df["F1"] = 2 * df['   metrics/precision(B)'] * df['      metrics/recall(B)'] / (df['   metrics/precision(B)'] + df['      metrics/recall(B)'])
    # Add a column for the name of the run
    df["run"] = r.parent.name
    dfs.append(df.iloc[-1])
df = pd.concat(dfs, axis=1).T
df
# Out:
#        metrics/precision(B)       metrics/recall(B)        metrics/mAP50(B)  \
# 97                  0.43756                 0.24679                  0.2466
# 51                  0.43479                 0.22365                 0.21688
# 63                  0.33829                 0.21691                 0.22238
# 59                  0.42597                 0.22374                 0.22386
# 52                  0.30055                 0.23689                 0.22528
# 57                  0.44206                 0.22766                 0.22623
# 71                  0.36003                 0.23032                 0.22464
# 52                  0.42725                 0.22979                 0.22766
# 88                  0.28988                 0.23279                 0.21867
# 60                  0.34403                 0.23781                 0.21721
# 83                  0.38781                 0.22598                 0.22404
# 52                  0.42942                 0.23341                 0.22936
# 88                  0.31668                 0.22055                  0.2223
# 96                  0.30052                 0.24132                 0.22585
# 51                    0.276                 0.21246                 0.20909
# 108                 0.38618                 0.22502                 0.23099
# 51                   0.4255                 0.23096                 0.22762
# 75                  0.47588                  0.2061                 0.23765
# 81                  0.45543                 0.20162                 0.21696
# 36                  0.38325                 0.23248                 0.23213
# 59                  0.44492                 0.22774                  0.2274
# 86                  0.50778                 0.20014                 0.21504
# 60                  0.43369                 0.23195                  0.2153
# 67                  0.35601                 0.21565                 0.22502
# 60                  0.37708                 0.22733                 0.22865
# 52                  0.31236                 0.22986                 0.22594
# 60                  0.35756                 0.23876                 0.21826
#
#         metrics/mAP50-95(B)        F1                                  run
# 97                  0.11071  0.315585     run0--freeze15_lrf1e-05_lr00.001
# 51                  0.09901  0.295367    run1--freeze15_lrf1e-05_lr00.0001
# 63                  0.10099  0.264332    run10--freeze15_lrf0.001_lr01e-05
# 59                   0.1025  0.293382    run11--freeze15_lrf0.001_lr01e-06
# 52                  0.10445   0.26495    run12--freeze20_lrf1e-05_lr00.001
# 57                  0.10398  0.300542   run13--freeze20_lrf1e-05_lr00.0001
# 71                  0.10312  0.280925    run14--freeze20_lrf1e-05_lr01e-05
# 52                  0.10388  0.298849    run15--freeze20_lrf1e-05_lr01e-06
# 88                  0.10161  0.258217   run16--freeze20_lrf0.0001_lr00.001
# 60                  0.10174  0.281224  run17--freeze20_lrf0.0001_lr00.0001
# 83                  0.10253  0.285561   run18--freeze20_lrf0.0001_lr01e-05
# 52                  0.10467  0.302433   run19--freeze20_lrf0.0001_lr01e-06
# 88                  0.10096  0.260014     run2--freeze15_lrf1e-05_lr01e-05
# 96                  0.10344  0.267686    run20--freeze20_lrf0.001_lr00.001
# 51                  0.09605  0.240097   run21--freeze20_lrf0.001_lr00.0001
# 108                 0.10624  0.284353    run22--freeze20_lrf0.001_lr01e-05
# 51                  0.10424  0.299404    run23--freeze20_lrf0.001_lr01e-06
# 75                  0.11461   0.28763    run24--freeze5_lrf0.0001_lr00.001
# 81                  0.10471  0.279503   run25--freeze5_lrf0.0001_lr00.0001
# 36                  0.10689  0.289406    run26--freeze5_lrf0.0001_lr01e-05
# 59                  0.10404   0.30127     run3--freeze15_lrf1e-05_lr01e-06
# 86                  0.10102  0.287115    run4--freeze15_lrf0.0001_lr00.001
# 60                  0.09979  0.302249   run5--freeze15_lrf0.0001_lr00.0001
# 67                  0.10199  0.268599    run6--freeze15_lrf0.0001_lr01e-05
# 60                  0.10447  0.283654    run7--freeze15_lrf0.0001_lr01e-06
# 52                  0.10082  0.264834     run8--freeze15_lrf0.001_lr00.001
# 60                  0.10301  0.286326    run9--freeze15_lrf0.001_lr00.0001

# %%
# Get the column names of the df
columns = list(df.columns)
columns
# Out:
# ['   metrics/precision(B)',
#  '      metrics/recall(B)',
#  '       metrics/mAP50(B)',
#  '    metrics/mAP50-95(B)',
#  'F1',
#  'run']

# %%
# Sort the dataframe by F1
df_f1 = df.sort_values("F1", ascending=False).head(n=5)
df_f1
# Out:
#       metrics/precision(B)       metrics/recall(B)        metrics/mAP50(B)  \
# 97                 0.43756                 0.24679                  0.2466
# 52                 0.42942                 0.23341                 0.22936
# 60                 0.43369                 0.23195                  0.2153
# 59                 0.44492                 0.22774                  0.2274
# 57                 0.44206                 0.22766                 0.22623
#
#        metrics/mAP50-95(B)        F1                                 run
# 97                 0.11071  0.315585    run0--freeze15_lrf1e-05_lr00.001
# 52                 0.10467  0.302433  run19--freeze20_lrf0.0001_lr01e-06
# 60                 0.09979  0.302249  run5--freeze15_lrf0.0001_lr00.0001
# 59                 0.10404   0.30127    run3--freeze15_lrf1e-05_lr01e-06
# 57                 0.10398  0.300542  run13--freeze20_lrf1e-05_lr00.0001

# %%
# Sort by mAP50
df_map50 = df.sort_values("       metrics/mAP50(B)", ascending=False).head(n=5)
df_map50
# Out:
#        metrics/precision(B)       metrics/recall(B)        metrics/mAP50(B)  \
# 97                  0.43756                 0.24679                  0.2466
# 75                  0.47588                  0.2061                 0.23765
# 36                  0.38325                 0.23248                 0.23213
# 108                 0.38618                 0.22502                 0.23099
# 52                  0.42942                 0.23341                 0.22936
#
#         metrics/mAP50-95(B)        F1                                 run
# 97                  0.11071  0.315585    run0--freeze15_lrf1e-05_lr00.001
# 75                  0.11461   0.28763   run24--freeze5_lrf0.0001_lr00.001
# 36                  0.10689  0.289406   run26--freeze5_lrf0.0001_lr01e-05
# 108                 0.10624  0.284353   run22--freeze20_lrf0.001_lr01e-05
# 52                  0.10467  0.302433  run19--freeze20_lrf0.0001_lr01e-06

# %%
df.sort_values("   metrics/precision(B)", ascending=False).head(n=5)
# Out:
#       metrics/precision(B)       metrics/recall(B)        metrics/mAP50(B)  \
# 86                 0.50778                 0.20014                 0.21504
# 75                 0.47588                  0.2061                 0.23765
# 81                 0.45543                 0.20162                 0.21696
# 59                 0.44492                 0.22774                  0.2274
# 57                 0.44206                 0.22766                 0.22623
#
#        metrics/mAP50-95(B)        F1                                 run
# 86                 0.10102  0.287115   run4--freeze15_lrf0.0001_lr00.001
# 75                 0.11461   0.28763   run24--freeze5_lrf0.0001_lr00.001
# 81                 0.10471  0.279503  run25--freeze5_lrf0.0001_lr00.0001
# 59                 0.10404   0.30127    run3--freeze15_lrf1e-05_lr01e-06
# 57                 0.10398  0.300542  run13--freeze20_lrf1e-05_lr00.0001

# %%
df.sort_values("      metrics/recall(B)", ascending=False).head(n=5)
# Out:
#       metrics/precision(B)       metrics/recall(B)        metrics/mAP50(B)  \
# 97                 0.43756                 0.24679                  0.2466
# 96                 0.30052                 0.24132                 0.22585
# 60                 0.35756                 0.23876                 0.21826
# 60                 0.34403                 0.23781                 0.21721
# 52                 0.30055                 0.23689                 0.22528
#
#        metrics/mAP50-95(B)        F1                                  run
# 97                 0.11071  0.315585     run0--freeze15_lrf1e-05_lr00.001
# 96                 0.10344  0.267686    run20--freeze20_lrf0.001_lr00.001
# 60                 0.10301  0.286326    run9--freeze15_lrf0.001_lr00.0001
# 60                 0.10174  0.281224  run17--freeze20_lrf0.0001_lr00.0001
# 52                 0.10445   0.26495    run12--freeze20_lrf1e-05_lr00.001

# %%
# Write the best 3 runs from df_f1['run'] to a text file
with open("best_f1.txt", "w") as f:
    for run in df_f1['run']:
        f.write(run + "\n")
